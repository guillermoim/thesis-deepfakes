# %% [markdown]
# Sequence Visualization

# %%
from training.datasets.classifier_dataset import DeepFakeClassifierDataset
import utils as U
from torch.utils.data import DataLoader
import torchvision
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = DeepFakeClassifierDataset(crops_dir='crops', data_path='data/train_data', hardcore=True, normalize=None, folds_csv='data/train_data/fold0.csv', fold = 1, transforms=U.create_train_transforms(300))
dataset.reset(2,1)
# Out:
# real 12818 fakes 12818 mode train

# %%
sampler = None
loader = DataLoader(dataset, batch_size=4, num_workers=8, shuffle=sampler is None, sampler=sampler, pin_memory=False, drop_last=True)

# %%
for i, (data) in enumerate(loader):
    grid = torchvision.utils.make_grid(data["image"], nrow=2)
    fig, ax = plt.subplots(1,1, figsize=(5,7))
    ax.imshow(np.transpose(grid.numpy(), (1,2,0)))
    ax.set_title(f' - face #{data["labels"].sum()}')
    ax.axis('off')
    plt.show()
    for x in zip(data['img_name'], data["labels"]):
        print(x)
    if i > 2:
        break
# Out:
# ('mxlipjhmqk/140_0.png', tensor([0.0100], dtype=torch.float64))
# ('xpzfhhwkwb/280_0.png', tensor([0.9900], dtype=torch.float64))
# ('nyyrcevhrc/280_0.png', tensor([0.0100], dtype=torch.float64))
# ('tyojwenpaf/160_0.png', tensor([0.0100], dtype=torch.float64))
# ('qxzuuzvpmg/70_1.png', tensor([0.0100], dtype=torch.float64))
# ('fgobmbcami/90_0.png', tensor([0.0100], dtype=torch.float64))
# ('xdezcezszc/170_0.png', tensor([0.0100], dtype=torch.float64))
# ('rlqbowounu/270_0.png', tensor([0.0100], dtype=torch.float64))
# ('rmhsahyvta/180_0.png', tensor([0.0100], dtype=torch.float64))
# ('zrhxaamlrw/0_0.png', tensor([0.9900], dtype=torch.float64))
# ('ypufjcamul/210_0.png', tensor([0.9900], dtype=torch.float64))
# ('hkqopvybph/20_0.png', tensor([0.9900], dtype=torch.float64))
# ('czfqlbcfpa/270_0.png', tensor([0.0100], dtype=torch.float64))
# ('fzmnxvmtgh/50_1.png', tensor([0.0100], dtype=torch.float64))
# ('pdswwyyntw/250_0.png', tensor([0.0100], dtype=torch.float64))
# ('ztyuiqrhdk/260_0.png', tensor([0.0100], dtype=torch.float64))

# %%
Images = 'data/train_data/crops/mueekicuyv/190_0.png', 'data/train_data/crops/hrztbthajc/290_0.png', 'data/train_data/crops/hkqopvybph/20_0.png', 'data/train_data/crops/xpzfhhwkwb/280_0.png'

# %%
import pandas as pd

# %%
df = pd.read_csv('data/train_data/folds.csv')
fo = df[(df.video +'/'+ df.file == 'mueekicuyv/190_0.png') | (df.video +'/'+ df.file == 'hrztbthajc/290_0.png') | (df.video +'/'+ df.file == 'hkqopvybph/20_0.png') | (df.video +'/'+ df.file == 'rmhsahyvta/180_0.png')] 

pd.to_csv('data/train_data/folds4.csv', index=False)
# Out:
#              video       file  label    original  frame  fold
# 160832  hrztbthajc  290_0.png      1  fnkdkfajak    290     0
# 242485  rmhsahyvta  180_0.png      0  rmhsahyvta    180     0
# 296924  mueekicuyv  190_0.png      0  mueekicuyv    190     0
# 350995  hkqopvybph   20_0.png      1  dmupfdcvca     20     0
